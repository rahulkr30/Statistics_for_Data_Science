# %%
import numpy as np
from scipy.integrate  import quad
from sklearn.neighbors import KernelDensity
import seaborn as sns
import matplotlib.pyplot as plt

# %%
x=np.linspace(1,20,100)

# %%
kde=KernelDensity(kernel='gaussian',bandwidth=0.5)

# %%
kde.fit(x.reshape(-1, 1))
# Out:
# KernelDensity(bandwidth=0.5)

# %%
pdf_func = lambda x: np.exp(kde.score_samples(np.array([[x]])))[0]

# %%
pdf, _ = quad(pdf_func, 1,6)

# %%
np.histogram(x,bins=21)
# Out:
# (array([5, 5, 5, 4, 5, 5, 4, 5, 5, 5, 4, 5, 5, 4, 5, 5, 5, 4, 5, 5, 5],
#        dtype=int64),
#  array([ 1.        ,  1.9047619 ,  2.80952381,  3.71428571,  4.61904762,
#          5.52380952,  6.42857143,  7.33333333,  8.23809524,  9.14285714,
#         10.04761905, 10.95238095, 11.85714286, 12.76190476, 13.66666667,
#         14.57142857, 15.47619048, 16.38095238, 17.28571429, 18.19047619,
#         19.0952381 , 20.        ]))

# %%
a=2
b=6
mu=x.mean()
sigma=x.std()

# %%
mu,sigma=stats.norm.fit(x)

# %%
df=sns.load_dataset('iris')

# %%
x=df.sepal_length
mean = np.mean(x)
std_dev = np.std(x)

# %%
x1=np.linspace(x.min(),x.max(),1000)

# %%
dist = stats.norm(x.mean(),x.std())

# %%
pdf=dist.pdf(x1)

# %%
cdf=dist.cdf(x1)

# %%
sns.ecdfplot(x)
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='Proportion'>

# %%
sns.kdeplot(x)
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='Density'>

# %%
plt.plot(x1,pdf)

# %%
cdf=dist.cdf(x)

# %%
plt.plot(x,cdf)

# %% [markdown]
# -- kerenal density function

# %%
kde=KernelDensity(kernel='gaussian',bandwidth=0.5)

# %%
kde.fit(np.array(x).reshape(-1,1))
# Out:
# KernelDensity(bandwidth=0.5)

# %%
sample=np.linspace(np.min(x),np.max(x),len(x)).reshape(-1, 1)

# %%
pdf=np.exp(kde.score_samples(sample))

# %%
plt.plot(sample,pdf)

# %%
cdf=pdf.cumsum()

# %%
plt.plot(sample,cdf/max(cdf))

# %%
cdf/=max(cdf)

# %%
# Out:
# array([0.00332118, 0.00681061, 0.01047157, 0.01430706, 0.01831973,
#        0.02251193, 0.02688565, 0.03144253, 0.03618381, 0.04111037,
#        0.04622269, 0.05152086, 0.05700455, 0.06267305, 0.06852524,
#        0.07455962, 0.0807743 , 0.087167  , 0.09373511, 0.10047564,
#        0.1073853 , 0.11446046, 0.12169723, 0.12909144, 0.13663868,
#        0.14433432, 0.15217354, 0.16015136, 0.16826267, 0.17650223,
#        0.18486474, 0.19334482, 0.20193708, 0.2106361 , 0.21943649,
#        0.2283329 , 0.23732002, 0.24639262, 0.25554558, 0.26477385,
#        0.27407253, 0.28343681, 0.29286205, 0.30234372, 0.31187745,
#        0.321459  , 0.33108429, 0.34074937, 0.35045042, 0.36018375,
#        0.36994581, 0.37973316, 0.38954245, 0.39937043, 0.40921395,
#        0.41906991, 0.42893528, 0.43880708, 0.44868236, 0.45855818,
#        0.46843162, 0.47829976, 0.48815965, 0.49800832, 0.50784278,
#        0.51765995, 0.52745674, 0.53722997, 0.54697639, 0.55669268,
# ...
